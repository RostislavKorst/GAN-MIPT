# %% [markdown]
# ## GAN model

# %% [markdown]
# In 2014, Ian Goodfellow and his colleagues at the University of Montreal published a stunning paper introducing the world to GANs, or generative adversarial networks. The models play two distinct (literally, adversarial) roles. Given some real data set R, G is the generator, trying to create fake data that looks just like the genuine data, while D is the discriminator, getting data from either the real set or G and labeling the difference. Goodfellow’s metaphor (and a fine one it is) was that G was like a team of forgers trying to match real paintings with their output, while D was the team of detectives trying to tell the difference. (Except that in this case, the forgers G never get to see the original data — only the judgments of D. They’re like blind forgers.)
#
# ![GAN](https://raw.githubusercontent.com/manhlab/practike-gan-2021/main/gan-mnist.png)
#
# Here's what we're going to do:
#
# - Define the parameters
# - Load the data (with transforms and normalization)
# - Denormalize for visual inspection of samples
# - Define the Discriminator network, the Generator network
# - Study the activation function: Leaky ReLU
# - Explain the output activation function: Tanh, Sigmoid
# - Look at some sample outputs
# - Define losses, optimizers and helper functions for training
#  - For discriminator
#  -  For generator
# - Train the model
# - Save intermediate generated images to file
# - Look at some outputs
# - Save the models
#
# ![MNIST](https://i.imgur.com/CAYnuo1.jpeg)

# %% [markdown]
# ### Define parameters & Load Dataset

# %%
import torch 
import torch.nn as nn
import numpy as np
import cv2
import matplotlib.pyplot as plt
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST
from IPython.display import Image
from torchvision.utils import save_image
from torch.utils.data import DataLoader

import os
# %matplotlib inline 
plt.style.use("ggplot")
hidden_size = 256 
batch_size = 100 
LR = 0.0002
num_epochs = 100
sample_dir = "./images"
latent_size = 64 # input random input vector latent
image_size = 784 # 28*28 flatten
device = 'cuda' if torch.cuda.is_available() else 'cpu'

if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)
## Define the dataset
mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
img, label = mnist[0]
print('Label: ', label)
# Посмотрим распределение чисел на картинке - вырежем часть размером 10 на 10, 
# вытянем в вектор и построим гистограмму
plt.hist(img[:,5:15,5:15].flatten(), bins=15)
# Out:
# Label:  5
# (array([55.,  4.,  3.,  0.,  3.,  2.,  1.,  0.,  1.,  3.,  1.,  3.,  2.,
#          1., 21.]),
#  array([-1.        , -0.86771244, -0.7354248 , -0.60313725, -0.47084966,
#         -0.3385621 , -0.20627451, -0.07398693,  0.05830066,  0.19058824,
#          0.32287583,  0.4551634 ,  0.587451  ,  0.71973854,  0.85202616,
#          0.9843137 ], dtype=float32),
#  <a list of 15 Patch objects>)

# %%
# denormalization image from range (-1)-1 to range 0-1 to display it
def denorm(x):
    return x * 0.5 + 0.5

# %%
# Построим распределение после денормализации
plt.hist(denorm(img)[:,5:15,5:15].flatten(), bins=15)
# Out:
# (array([55.,  4.,  3.,  0.,  3.,  2.,  1.,  0.,  1.,  3.,  1.,  3.,  2.,
#          1., 21.]),
#  array([0.        , 0.06614379, 0.13228758, 0.19843137, 0.26457515,
#         0.33071896, 0.39686275, 0.46300653, 0.5291503 , 0.5952941 ,
#         0.6614379 , 0.7275817 , 0.7937255 , 0.8598693 , 0.92601305,
#         0.99215686], dtype=float32),
#  <a list of 15 Patch objects>)

# %%
# show  image sample with matplotlib
plt.imshow(denorm(img)[0])
plt.show()

# %%
# define the dataloader
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %% [markdown]
# GAN состоит из двух глубоких сетей, генератора и дискриминатора. генератор создает изображения, прежде чем научиться его обучать. Поскольку дискриминатор представляет собой модель бинарной классификации, мы можем использовать функцию потери бинарной кросс-энтропии для количественной оценки того, насколько хорошо он может различать реальные и сгенерированные изображения.
#
# ![](https://raw.githubusercontent.com/manhlab/practike-gan-2021/main/generator.png)
#
# ![](https://raw.githubusercontent.com/manhlab/practike-gan-2021/main/discriminator.png)

# %%
class Generator(nn.Module):
    def __init__(self, latent_size, image_size, hidden_size):
        super(Generator, self).__init__()
        ## set a linear layer with input size is latent_size and output size is hidden_size
        self.linear1 = nn.Linear(latent_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is hidden_size
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is image_size
        self.linear3 = nn.Linear(hidden_size, image_size)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

    def forward(self, x):
        # forward x -> linear1 -> relu -> linear2 -> relu -> linear3 -> tanh
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.linear3(x)
        x = self.tanh(x)
        return x

class Discriminator(nn.Module):
    def __init__(self, image_size, hidden_size):
        super(Discriminator, self).__init__()
        ## set a linear layer with input size is image_size and output size is hidden_size
        self.linear1 = nn.Linear(image_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is hidden_size
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is 1
        self.linear3 = nn.Linear(hidden_size, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        # forward x -> linear1 -> relu -> linear2 -> relu -> linear3 -> sigmoid
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.linear3(x)
        x = self.sigmoid(x)
        return x

# %% [markdown]
# ## Create the Generator and Discriminator

# %%
# create new Generator model
G = Generator(latent_size, image_size, hidden_size)
# create new Discriminator model
D = Discriminator(image_size, hidden_size)

# %%
# show the output of model 
y = G(torch.randn(2, latent_size))
# Вывод необученного генератора
plt.imshow(denorm(y.detach().reshape(2, 28, 28))[0])
plt.show()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# define the criterion is nn.BCELoss()
criterion = nn.BCELoss()
## Define the optimizer for generator and discrimator
optimizer_g = torch.optim.Adam(G.parameters(), lr=LR)
optimizer_d = torch.optim.Adam(D.parameters(), lr=LR)

# %% [markdown]
# Discriminator Training

# %%
def reset_grad():
    ## reset gradient for optimizer of generator and discrimator
    optimizer_g.zero_grad()
    optimizer_d.zero_grad()

def train_discriminator(images):
  
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    
    outputs = D(images).to(device)
    # Loss for real images
    d_loss = criterion(outputs, real_labels)
    real_score = torch.mean(outputs)

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images).to(device)

    g_loss = criterion(outputs, fake_labels)
    fake_score = torch.mean(outputs)

    # Sum losses
    loss = d_loss + g_loss

    # Reset gradients
    reset_grad()

    # Compute gradients
    loss.backward()

    # Adjust the parameters using backprop
    optimizer_d.step()
    
    return loss, real_score, fake_score

# %% [markdown]
# Generator Training

# %%
def train_generator():
    # Generate fake images and calculate loss
    # z = torch.randn(batch_size, latent_size).to(device)
    z = torch.Tensor(np.random.normal(0, 1, (batch_size, latent_size))).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    # calculate the generator loss
    loss = criterion(D(fake_images), labels)
    
    # Reset gradients
    reset_grad()
    # Backprop and optimize
    loss.backward()
    optimizer_g.step()

    return loss, fake_images

# %% [markdown]
# ## Start the training proccess

# %%
# function to save the sample output of generator
def save_fake_images(index):
    # sample_vectors = torch.randn(batch_size, latent_size).to(device)
    sample_vectors = torch.Tensor(np.random.normal(0, 1, (batch_size, latent_size))).to(device)
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# %%
# %%time
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []
G.to(device)
D.to(device)
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator  
        d_loss, real_score, fake_score = train_discriminator(images)
        # Train the generator
        g_loss, _ = train_generator()
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/100], Step [200/600], d_loss: 0.6614, g_loss: 1.8940, D(x): 0.74, D(G(z)): 0.21
# Epoch [0/100], Step [400/600], d_loss: 0.8308, g_loss: 1.6192, D(x): 0.73, D(G(z)): 0.31
# Epoch [0/100], Step [600/600], d_loss: 0.8999, g_loss: 1.5825, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0001.png
# Epoch [1/100], Step [200/600], d_loss: 1.0308, g_loss: 1.3780, D(x): 0.66, D(G(z)): 0.28
# Epoch [1/100], Step [400/600], d_loss: 0.8806, g_loss: 1.7724, D(x): 0.71, D(G(z)): 0.28
# Epoch [1/100], Step [600/600], d_loss: 1.0742, g_loss: 1.5507, D(x): 0.70, D(G(z)): 0.36
# Saving fake_images-0002.png
# Epoch [2/100], Step [200/600], d_loss: 0.8157, g_loss: 1.4684, D(x): 0.75, D(G(z)): 0.31
# Epoch [2/100], Step [400/600], d_loss: 0.7205, g_loss: 1.6638, D(x): 0.81, D(G(z)): 0.30
# Epoch [2/100], Step [600/600], d_loss: 0.7932, g_loss: 1.9551, D(x): 0.78, D(G(z)): 0.32
# Saving fake_images-0003.png
# Epoch [3/100], Step [200/600], d_loss: 0.7617, g_loss: 1.6136, D(x): 0.73, D(G(z)): 0.25
# Epoch [3/100], Step [400/600], d_loss: 0.8032, g_loss: 1.7618, D(x): 0.73, D(G(z)): 0.28
# Epoch [3/100], Step [600/600], d_loss: 0.7228, g_loss: 1.8824, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0004.png
# Epoch [4/100], Step [200/600], d_loss: 1.0409, g_loss: 1.3512, D(x): 0.69, D(G(z)): 0.36
# Epoch [4/100], Step [400/600], d_loss: 0.9462, g_loss: 1.9051, D(x): 0.70, D(G(z)): 0.29
# Epoch [4/100], Step [600/600], d_loss: 1.0822, g_loss: 1.4990, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0005.png
# Epoch [5/100], Step [200/600], d_loss: 1.1547, g_loss: 1.7002, D(x): 0.66, D(G(z)): 0.35
# Epoch [5/100], Step [400/600], d_loss: 0.8497, g_loss: 1.3002, D(x): 0.78, D(G(z)): 0.35
# Epoch [5/100], Step [600/600], d_loss: 0.8132, g_loss: 1.9677, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0006.png
# Epoch [6/100], Step [200/600], d_loss: 0.9740, g_loss: 1.4947, D(x): 0.71, D(G(z)): 0.35
# Epoch [6/100], Step [400/600], d_loss: 0.9575, g_loss: 1.9576, D(x): 0.64, D(G(z)): 0.23
# Epoch [6/100], Step [600/600], d_loss: 0.8721, g_loss: 1.7321, D(x): 0.67, D(G(z)): 0.21
# Saving fake_images-0007.png
# Epoch [7/100], Step [200/600], d_loss: 0.9632, g_loss: 1.9295, D(x): 0.65, D(G(z)): 0.25
# Epoch [7/100], Step [400/600], d_loss: 0.9538, g_loss: 1.7897, D(x): 0.69, D(G(z)): 0.30
# Epoch [7/100], Step [600/600], d_loss: 0.9477, g_loss: 1.6536, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0008.png
# Epoch [8/100], Step [200/600], d_loss: 0.7923, g_loss: 1.6084, D(x): 0.78, D(G(z)): 0.31
# Epoch [8/100], Step [400/600], d_loss: 1.0347, g_loss: 1.6270, D(x): 0.71, D(G(z)): 0.36
# Epoch [8/100], Step [600/600], d_loss: 1.0670, g_loss: 1.6333, D(x): 0.63, D(G(z)): 0.30
# Saving fake_images-0009.png
# Epoch [9/100], Step [200/600], d_loss: 0.9432, g_loss: 1.7723, D(x): 0.69, D(G(z)): 0.32
# Epoch [9/100], Step [400/600], d_loss: 0.9222, g_loss: 1.8248, D(x): 0.68, D(G(z)): 0.28
# Epoch [9/100], Step [600/600], d_loss: 0.8163, g_loss: 1.7522, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0010.png
# Epoch [10/100], Step [200/600], d_loss: 0.9159, g_loss: 1.2452, D(x): 0.79, D(G(z)): 0.40
# Epoch [10/100], Step [400/600], d_loss: 0.8673, g_loss: 2.0084, D(x): 0.77, D(G(z)): 0.32
# Epoch [10/100], Step [600/600], d_loss: 1.0226, g_loss: 1.5340, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0011.png
# Epoch [11/100], Step [200/600], d_loss: 1.0741, g_loss: 1.6023, D(x): 0.68, D(G(z)): 0.34
# Epoch [11/100], Step [400/600], d_loss: 0.9327, g_loss: 1.3138, D(x): 0.73, D(G(z)): 0.35
# Epoch [11/100], Step [600/600], d_loss: 0.9568, g_loss: 1.5871, D(x): 0.76, D(G(z)): 0.39
# Saving fake_images-0012.png
# Epoch [12/100], Step [200/600], d_loss: 0.9481, g_loss: 1.4566, D(x): 0.73, D(G(z)): 0.34
# Epoch [12/100], Step [400/600], d_loss: 1.0000, g_loss: 1.6174, D(x): 0.75, D(G(z)): 0.40
# Epoch [12/100], Step [600/600], d_loss: 1.0318, g_loss: 1.6454, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0013.png
# Epoch [13/100], Step [200/600], d_loss: 0.8906, g_loss: 1.5205, D(x): 0.73, D(G(z)): 0.32
# Epoch [13/100], Step [400/600], d_loss: 0.9114, g_loss: 1.7860, D(x): 0.72, D(G(z)): 0.29
# Epoch [13/100], Step [600/600], d_loss: 0.7101, g_loss: 1.9846, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0014.png
# Epoch [14/100], Step [200/600], d_loss: 0.9333, g_loss: 1.5145, D(x): 0.66, D(G(z)): 0.25
# Epoch [14/100], Step [400/600], d_loss: 1.0230, g_loss: 1.8161, D(x): 0.64, D(G(z)): 0.28
# Epoch [14/100], Step [600/600], d_loss: 1.0233, g_loss: 1.8670, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0015.png
# Epoch [15/100], Step [200/600], d_loss: 0.9027, g_loss: 1.8116, D(x): 0.70, D(G(z)): 0.28
# Epoch [15/100], Step [400/600], d_loss: 0.7776, g_loss: 1.7879, D(x): 0.72, D(G(z)): 0.25
# Epoch [15/100], Step [600/600], d_loss: 1.0093, g_loss: 1.4566, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0016.png
# Epoch [16/100], Step [200/600], d_loss: 0.8216, g_loss: 1.6486, D(x): 0.75, D(G(z)): 0.32
# Epoch [16/100], Step [400/600], d_loss: 0.8292, g_loss: 1.5695, D(x): 0.73, D(G(z)): 0.29
# Epoch [16/100], Step [600/600], d_loss: 0.9616, g_loss: 1.6233, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0017.png
# Epoch [17/100], Step [200/600], d_loss: 0.9103, g_loss: 1.3302, D(x): 0.75, D(G(z)): 0.36
# Epoch [17/100], Step [400/600], d_loss: 0.8570, g_loss: 1.5007, D(x): 0.76, D(G(z)): 0.33
# Epoch [17/100], Step [600/600], d_loss: 1.0443, g_loss: 1.6240, D(x): 0.62, D(G(z)): 0.28
# Saving fake_images-0018.png
# Epoch [18/100], Step [200/600], d_loss: 1.1568, g_loss: 1.4458, D(x): 0.63, D(G(z)): 0.33
# Epoch [18/100], Step [400/600], d_loss: 0.9871, g_loss: 1.6547, D(x): 0.72, D(G(z)): 0.35
# Epoch [18/100], Step [600/600], d_loss: 0.9538, g_loss: 1.8954, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0019.png
# Epoch [19/100], Step [200/600], d_loss: 0.9466, g_loss: 1.3152, D(x): 0.76, D(G(z)): 0.36
# Epoch [19/100], Step [400/600], d_loss: 0.8789, g_loss: 2.0125, D(x): 0.67, D(G(z)): 0.27
# Epoch [19/100], Step [600/600], d_loss: 0.8477, g_loss: 1.8504, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0020.png
# Epoch [20/100], Step [200/600], d_loss: 0.8446, g_loss: 1.6332, D(x): 0.71, D(G(z)): 0.28
# Epoch [20/100], Step [400/600], d_loss: 0.9788, g_loss: 1.4279, D(x): 0.76, D(G(z)): 0.37
# Epoch [20/100], Step [600/600], d_loss: 0.8387, g_loss: 1.6493, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0021.png
# Epoch [21/100], Step [200/600], d_loss: 1.0513, g_loss: 1.3114, D(x): 0.73, D(G(z)): 0.40
# Epoch [21/100], Step [400/600], d_loss: 0.8645, g_loss: 1.8417, D(x): 0.68, D(G(z)): 0.25
# Epoch [21/100], Step [600/600], d_loss: 0.9248, g_loss: 1.4960, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0022.png
# Epoch [22/100], Step [200/600], d_loss: 1.0938, g_loss: 1.1885, D(x): 0.69, D(G(z)): 0.38
# Epoch [22/100], Step [400/600], d_loss: 0.8785, g_loss: 1.6346, D(x): 0.67, D(G(z)): 0.28
# Epoch [22/100], Step [600/600], d_loss: 0.9660, g_loss: 1.6824, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0023.png
# Epoch [23/100], Step [200/600], d_loss: 0.9762, g_loss: 1.8301, D(x): 0.71, D(G(z)): 0.31
# Epoch [23/100], Step [400/600], d_loss: 0.9094, g_loss: 1.9702, D(x): 0.70, D(G(z)): 0.29
# Epoch [23/100], Step [600/600], d_loss: 0.9122, g_loss: 1.7779, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0024.png
# Epoch [24/100], Step [200/600], d_loss: 0.9615, g_loss: 1.6677, D(x): 0.69, D(G(z)): 0.31
# Epoch [24/100], Step [400/600], d_loss: 0.8854, g_loss: 1.5964, D(x): 0.71, D(G(z)): 0.28
# Epoch [24/100], Step [600/600], d_loss: 1.0082, g_loss: 1.6754, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0025.png
# Epoch [25/100], Step [200/600], d_loss: 0.8489, g_loss: 1.3919, D(x): 0.74, D(G(z)): 0.34
# Epoch [25/100], Step [400/600], d_loss: 0.9514, g_loss: 1.3339, D(x): 0.79, D(G(z)): 0.40
# Epoch [25/100], Step [600/600], d_loss: 1.0132, g_loss: 1.2106, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0026.png
# Epoch [26/100], Step [200/600], d_loss: 0.9808, g_loss: 1.4109, D(x): 0.68, D(G(z)): 0.31
# Epoch [26/100], Step [400/600], d_loss: 1.0326, g_loss: 1.3938, D(x): 0.70, D(G(z)): 0.36
# Epoch [26/100], Step [600/600], d_loss: 0.8544, g_loss: 1.7509, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0027.png
# Epoch [27/100], Step [200/600], d_loss: 0.8279, g_loss: 1.6324, D(x): 0.69, D(G(z)): 0.24
# Epoch [27/100], Step [400/600], d_loss: 0.9852, g_loss: 1.7210, D(x): 0.63, D(G(z)): 0.25
# Epoch [27/100], Step [600/600], d_loss: 0.8504, g_loss: 1.9053, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0028.png
# Epoch [28/100], Step [200/600], d_loss: 0.8167, g_loss: 1.2659, D(x): 0.79, D(G(z)): 0.34
# Epoch [28/100], Step [400/600], d_loss: 0.8218, g_loss: 1.6727, D(x): 0.69, D(G(z)): 0.25
# Epoch [28/100], Step [600/600], d_loss: 0.9132, g_loss: 1.2554, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0029.png
# Epoch [29/100], Step [200/600], d_loss: 0.7638, g_loss: 1.7886, D(x): 0.68, D(G(z)): 0.22
# Epoch [29/100], Step [400/600], d_loss: 1.0143, g_loss: 1.3640, D(x): 0.61, D(G(z)): 0.27
# Epoch [29/100], Step [600/600], d_loss: 0.8944, g_loss: 1.9815, D(x): 0.66, D(G(z)): 0.24
# Saving fake_images-0030.png
# Epoch [30/100], Step [200/600], d_loss: 0.8868, g_loss: 1.2841, D(x): 0.71, D(G(z)): 0.30
# Epoch [30/100], Step [400/600], d_loss: 1.0400, g_loss: 1.4558, D(x): 0.61, D(G(z)): 0.29
# Epoch [30/100], Step [600/600], d_loss: 0.9558, g_loss: 1.6162, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0031.png
# Epoch [31/100], Step [200/600], d_loss: 0.9593, g_loss: 1.8258, D(x): 0.69, D(G(z)): 0.31
# Epoch [31/100], Step [400/600], d_loss: 0.9503, g_loss: 1.9096, D(x): 0.66, D(G(z)): 0.28
# Epoch [31/100], Step [600/600], d_loss: 0.9041, g_loss: 1.4667, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0032.png
# Epoch [32/100], Step [200/600], d_loss: 0.6699, g_loss: 1.3163, D(x): 0.78, D(G(z)): 0.28
# Epoch [32/100], Step [400/600], d_loss: 0.9549, g_loss: 1.5175, D(x): 0.65, D(G(z)): 0.28
# Epoch [32/100], Step [600/600], d_loss: 0.8147, g_loss: 1.9001, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0033.png
# Epoch [33/100], Step [200/600], d_loss: 0.8575, g_loss: 1.5805, D(x): 0.71, D(G(z)): 0.30
# Epoch [33/100], Step [400/600], d_loss: 0.8166, g_loss: 1.7973, D(x): 0.76, D(G(z)): 0.31
# Epoch [33/100], Step [600/600], d_loss: 0.7108, g_loss: 1.6430, D(x): 0.72, D(G(z)): 0.20
# Saving fake_images-0034.png
# Epoch [34/100], Step [200/600], d_loss: 0.9321, g_loss: 1.8355, D(x): 0.70, D(G(z)): 0.29
# Epoch [34/100], Step [400/600], d_loss: 0.9721, g_loss: 1.4967, D(x): 0.67, D(G(z)): 0.29
# Epoch [34/100], Step [600/600], d_loss: 1.0532, g_loss: 1.6190, D(x): 0.65, D(G(z)): 0.32
# Saving fake_images-0035.png
# Epoch [35/100], Step [200/600], d_loss: 0.9510, g_loss: 1.7327, D(x): 0.62, D(G(z)): 0.25
# Epoch [35/100], Step [400/600], d_loss: 1.0413, g_loss: 1.7989, D(x): 0.67, D(G(z)): 0.31
# Epoch [35/100], Step [600/600], d_loss: 0.8241, g_loss: 1.6663, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0036.png
# Epoch [36/100], Step [200/600], d_loss: 0.7635, g_loss: 1.8704, D(x): 0.71, D(G(z)): 0.23
# Epoch [36/100], Step [400/600], d_loss: 0.9138, g_loss: 1.5611, D(x): 0.70, D(G(z)): 0.31
# Epoch [36/100], Step [600/600], d_loss: 0.7643, g_loss: 1.6982, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0037.png
# Epoch [37/100], Step [200/600], d_loss: 0.7869, g_loss: 1.6137, D(x): 0.73, D(G(z)): 0.26
# Epoch [37/100], Step [400/600], d_loss: 1.0124, g_loss: 1.2776, D(x): 0.70, D(G(z)): 0.37
# Epoch [37/100], Step [600/600], d_loss: 0.9318, g_loss: 1.8463, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0038.png
# Epoch [38/100], Step [200/600], d_loss: 0.8551, g_loss: 1.5525, D(x): 0.70, D(G(z)): 0.27
# Epoch [38/100], Step [400/600], d_loss: 0.7731, g_loss: 2.0118, D(x): 0.67, D(G(z)): 0.21
# Epoch [38/100], Step [600/600], d_loss: 0.8393, g_loss: 1.5924, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0039.png
# Epoch [39/100], Step [200/600], d_loss: 0.8699, g_loss: 1.4730, D(x): 0.70, D(G(z)): 0.28
# Epoch [39/100], Step [400/600], d_loss: 0.8904, g_loss: 1.3312, D(x): 0.73, D(G(z)): 0.34
# Epoch [39/100], Step [600/600], d_loss: 0.9685, g_loss: 1.4391, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0040.png
# Epoch [40/100], Step [200/600], d_loss: 0.8773, g_loss: 1.3801, D(x): 0.73, D(G(z)): 0.33
# Epoch [40/100], Step [400/600], d_loss: 0.8634, g_loss: 1.5222, D(x): 0.69, D(G(z)): 0.28
# Epoch [40/100], Step [600/600], d_loss: 0.8024, g_loss: 1.5495, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0041.png
# Epoch [41/100], Step [200/600], d_loss: 0.9630, g_loss: 1.6159, D(x): 0.69, D(G(z)): 0.35
# Epoch [41/100], Step [400/600], d_loss: 0.9432, g_loss: 1.5421, D(x): 0.70, D(G(z)): 0.30
# Epoch [41/100], Step [600/600], d_loss: 0.9122, g_loss: 1.5203, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0042.png
# Epoch [42/100], Step [200/600], d_loss: 0.8955, g_loss: 1.7467, D(x): 0.72, D(G(z)): 0.30
# Epoch [42/100], Step [400/600], d_loss: 0.9036, g_loss: 1.4987, D(x): 0.71, D(G(z)): 0.33
# Epoch [42/100], Step [600/600], d_loss: 0.9360, g_loss: 1.4963, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0043.png
# Epoch [43/100], Step [200/600], d_loss: 0.9228, g_loss: 1.4330, D(x): 0.66, D(G(z)): 0.29
# Epoch [43/100], Step [400/600], d_loss: 0.9570, g_loss: 1.4999, D(x): 0.69, D(G(z)): 0.32
# Epoch [43/100], Step [600/600], d_loss: 0.9647, g_loss: 1.5767, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0044.png
# Epoch [44/100], Step [200/600], d_loss: 0.9317, g_loss: 1.6158, D(x): 0.71, D(G(z)): 0.33
# Epoch [44/100], Step [400/600], d_loss: 1.0465, g_loss: 1.5342, D(x): 0.63, D(G(z)): 0.32
# Epoch [44/100], Step [600/600], d_loss: 0.9085, g_loss: 1.6345, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0045.png
# Epoch [45/100], Step [200/600], d_loss: 0.8834, g_loss: 1.3402, D(x): 0.70, D(G(z)): 0.29
# Epoch [45/100], Step [400/600], d_loss: 1.0303, g_loss: 1.4756, D(x): 0.68, D(G(z)): 0.35
# Epoch [45/100], Step [600/600], d_loss: 0.9323, g_loss: 1.6438, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0046.png
# Epoch [46/100], Step [200/600], d_loss: 1.0439, g_loss: 1.6090, D(x): 0.67, D(G(z)): 0.31
# Epoch [46/100], Step [400/600], d_loss: 1.1150, g_loss: 1.4732, D(x): 0.62, D(G(z)): 0.33
# Epoch [46/100], Step [600/600], d_loss: 0.7895, g_loss: 1.7259, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0047.png
# Epoch [47/100], Step [200/600], d_loss: 0.8286, g_loss: 1.6094, D(x): 0.75, D(G(z)): 0.31
# Epoch [47/100], Step [400/600], d_loss: 0.9104, g_loss: 1.5919, D(x): 0.68, D(G(z)): 0.28
# Epoch [47/100], Step [600/600], d_loss: 0.8918, g_loss: 1.6549, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0048.png
# Epoch [48/100], Step [200/600], d_loss: 0.8829, g_loss: 1.8178, D(x): 0.73, D(G(z)): 0.33
# Epoch [48/100], Step [400/600], d_loss: 0.9737, g_loss: 1.3525, D(x): 0.75, D(G(z)): 0.36
# Epoch [48/100], Step [600/600], d_loss: 0.9380, g_loss: 1.5617, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0049.png
# Epoch [49/100], Step [200/600], d_loss: 1.1927, g_loss: 1.4279, D(x): 0.62, D(G(z)): 0.38
# Epoch [49/100], Step [400/600], d_loss: 0.8121, g_loss: 1.4899, D(x): 0.71, D(G(z)): 0.29
# Epoch [49/100], Step [600/600], d_loss: 1.0766, g_loss: 1.5302, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0050.png
# Epoch [50/100], Step [200/600], d_loss: 0.9787, g_loss: 1.1047, D(x): 0.77, D(G(z)): 0.41
# Epoch [50/100], Step [400/600], d_loss: 1.1052, g_loss: 1.3488, D(x): 0.62, D(G(z)): 0.30
# Epoch [50/100], Step [600/600], d_loss: 1.0766, g_loss: 1.4689, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0051.png
# Epoch [51/100], Step [200/600], d_loss: 0.8370, g_loss: 1.7067, D(x): 0.75, D(G(z)): 0.31
# Epoch [51/100], Step [400/600], d_loss: 1.0011, g_loss: 1.5337, D(x): 0.63, D(G(z)): 0.28
# Epoch [51/100], Step [600/600], d_loss: 0.8877, g_loss: 1.3841, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0052.png
# Epoch [52/100], Step [200/600], d_loss: 0.7970, g_loss: 1.5289, D(x): 0.72, D(G(z)): 0.28
# Epoch [52/100], Step [400/600], d_loss: 0.8808, g_loss: 1.4752, D(x): 0.71, D(G(z)): 0.30
# Epoch [52/100], Step [600/600], d_loss: 0.9984, g_loss: 1.3251, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0053.png
# Epoch [53/100], Step [200/600], d_loss: 1.0126, g_loss: 1.3572, D(x): 0.71, D(G(z)): 0.36
# Epoch [53/100], Step [400/600], d_loss: 0.9545, g_loss: 1.4437, D(x): 0.69, D(G(z)): 0.30
# Epoch [53/100], Step [600/600], d_loss: 0.8094, g_loss: 1.3441, D(x): 0.78, D(G(z)): 0.34
# Saving fake_images-0054.png
# Epoch [54/100], Step [200/600], d_loss: 1.0402, g_loss: 1.3991, D(x): 0.68, D(G(z)): 0.35
# Epoch [54/100], Step [400/600], d_loss: 0.8454, g_loss: 1.5230, D(x): 0.68, D(G(z)): 0.25
# Epoch [54/100], Step [600/600], d_loss: 0.9528, g_loss: 1.4168, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0055.png
# Epoch [55/100], Step [200/600], d_loss: 0.8527, g_loss: 1.2767, D(x): 0.74, D(G(z)): 0.32
# Epoch [55/100], Step [400/600], d_loss: 0.9326, g_loss: 1.5629, D(x): 0.74, D(G(z)): 0.34
# Epoch [55/100], Step [600/600], d_loss: 1.1151, g_loss: 1.6097, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0056.png
# Epoch [56/100], Step [200/600], d_loss: 0.9128, g_loss: 1.3948, D(x): 0.67, D(G(z)): 0.28
# Epoch [56/100], Step [400/600], d_loss: 0.9899, g_loss: 1.4856, D(x): 0.66, D(G(z)): 0.31
# Epoch [56/100], Step [600/600], d_loss: 0.8890, g_loss: 1.5587, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0057.png
# Epoch [57/100], Step [200/600], d_loss: 0.8548, g_loss: 1.7190, D(x): 0.67, D(G(z)): 0.28
# Epoch [57/100], Step [400/600], d_loss: 0.9150, g_loss: 1.5179, D(x): 0.69, D(G(z)): 0.32
# Epoch [57/100], Step [600/600], d_loss: 0.9034, g_loss: 1.3657, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0058.png
# Epoch [58/100], Step [200/600], d_loss: 0.9025, g_loss: 1.5156, D(x): 0.72, D(G(z)): 0.32
# Epoch [58/100], Step [400/600], d_loss: 0.9825, g_loss: 1.7802, D(x): 0.67, D(G(z)): 0.28
# Epoch [58/100], Step [600/600], d_loss: 0.9666, g_loss: 1.5976, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0059.png
# Epoch [59/100], Step [200/600], d_loss: 1.1743, g_loss: 1.2845, D(x): 0.65, D(G(z)): 0.37
# Epoch [59/100], Step [400/600], d_loss: 0.8867, g_loss: 1.5136, D(x): 0.74, D(G(z)): 0.33
# Epoch [59/100], Step [600/600], d_loss: 0.8569, g_loss: 1.5188, D(x): 0.75, D(G(z)): 0.32
# Saving fake_images-0060.png
# Epoch [60/100], Step [200/600], d_loss: 0.7547, g_loss: 1.6881, D(x): 0.76, D(G(z)): 0.30
# Epoch [60/100], Step [400/600], d_loss: 0.8385, g_loss: 1.8723, D(x): 0.68, D(G(z)): 0.25
# Epoch [60/100], Step [600/600], d_loss: 1.0215, g_loss: 1.5263, D(x): 0.69, D(G(z)): 0.36
# Saving fake_images-0061.png
# Epoch [61/100], Step [200/600], d_loss: 0.8564, g_loss: 1.5994, D(x): 0.78, D(G(z)): 0.35
# Epoch [61/100], Step [400/600], d_loss: 1.0992, g_loss: 1.3005, D(x): 0.67, D(G(z)): 0.36
# Epoch [61/100], Step [600/600], d_loss: 0.9892, g_loss: 1.4569, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0062.png
# Epoch [62/100], Step [200/600], d_loss: 0.9140, g_loss: 1.5157, D(x): 0.77, D(G(z)): 0.40
# Epoch [62/100], Step [400/600], d_loss: 0.8468, g_loss: 1.5255, D(x): 0.69, D(G(z)): 0.28
# Epoch [62/100], Step [600/600], d_loss: 1.1508, g_loss: 1.3414, D(x): 0.64, D(G(z)): 0.35
# Saving fake_images-0063.png
# Epoch [63/100], Step [200/600], d_loss: 0.8917, g_loss: 1.2840, D(x): 0.72, D(G(z)): 0.34
# Epoch [63/100], Step [400/600], d_loss: 0.9743, g_loss: 1.5196, D(x): 0.70, D(G(z)): 0.31
# Epoch [63/100], Step [600/600], d_loss: 0.8646, g_loss: 1.4999, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0064.png
# Epoch [64/100], Step [200/600], d_loss: 0.8660, g_loss: 1.7956, D(x): 0.68, D(G(z)): 0.28
# Epoch [64/100], Step [400/600], d_loss: 0.9189, g_loss: 1.2961, D(x): 0.76, D(G(z)): 0.35
# Epoch [64/100], Step [600/600], d_loss: 1.1030, g_loss: 1.6485, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0065.png
# Epoch [65/100], Step [200/600], d_loss: 1.0884, g_loss: 1.1588, D(x): 0.72, D(G(z)): 0.40
# Epoch [65/100], Step [400/600], d_loss: 0.8992, g_loss: 1.7894, D(x): 0.72, D(G(z)): 0.34
# Epoch [65/100], Step [600/600], d_loss: 1.0966, g_loss: 1.4641, D(x): 0.61, D(G(z)): 0.30
# Saving fake_images-0066.png
# Epoch [66/100], Step [200/600], d_loss: 1.0528, g_loss: 1.3003, D(x): 0.65, D(G(z)): 0.35
# Epoch [66/100], Step [400/600], d_loss: 0.9465, g_loss: 1.4962, D(x): 0.70, D(G(z)): 0.30
# Epoch [66/100], Step [600/600], d_loss: 0.9837, g_loss: 1.4191, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0067.png
# Epoch [67/100], Step [200/600], d_loss: 1.1517, g_loss: 1.4655, D(x): 0.64, D(G(z)): 0.37
# Epoch [67/100], Step [400/600], d_loss: 1.3094, g_loss: 1.6569, D(x): 0.55, D(G(z)): 0.32
# Epoch [67/100], Step [600/600], d_loss: 0.8621, g_loss: 1.5279, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0068.png
# Epoch [68/100], Step [200/600], d_loss: 1.0303, g_loss: 1.2473, D(x): 0.73, D(G(z)): 0.37
# Epoch [68/100], Step [400/600], d_loss: 1.0267, g_loss: 1.7181, D(x): 0.70, D(G(z)): 0.36
# Epoch [68/100], Step [600/600], d_loss: 1.0117, g_loss: 1.4210, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0069.png
# Epoch [69/100], Step [200/600], d_loss: 0.9010, g_loss: 1.3650, D(x): 0.74, D(G(z)): 0.33
# Epoch [69/100], Step [400/600], d_loss: 0.7692, g_loss: 1.7913, D(x): 0.72, D(G(z)): 0.27
# Epoch [69/100], Step [600/600], d_loss: 0.8462, g_loss: 1.9358, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0070.png
# Epoch [70/100], Step [200/600], d_loss: 0.8157, g_loss: 1.5224, D(x): 0.74, D(G(z)): 0.29
# Epoch [70/100], Step [400/600], d_loss: 0.9302, g_loss: 1.4079, D(x): 0.69, D(G(z)): 0.29
# Epoch [70/100], Step [600/600], d_loss: 0.9510, g_loss: 1.4670, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0071.png
# Epoch [71/100], Step [200/600], d_loss: 0.8563, g_loss: 1.4885, D(x): 0.71, D(G(z)): 0.28
# Epoch [71/100], Step [400/600], d_loss: 1.0065, g_loss: 1.4861, D(x): 0.65, D(G(z)): 0.30
# Epoch [71/100], Step [600/600], d_loss: 0.8995, g_loss: 1.9641, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0072.png
# Epoch [72/100], Step [200/600], d_loss: 0.7948, g_loss: 1.4714, D(x): 0.73, D(G(z)): 0.27
# Epoch [72/100], Step [400/600], d_loss: 0.9066, g_loss: 1.6010, D(x): 0.68, D(G(z)): 0.30
# Epoch [72/100], Step [600/600], d_loss: 0.8001, g_loss: 1.4930, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0073.png
# Epoch [73/100], Step [200/600], d_loss: 0.9527, g_loss: 1.7549, D(x): 0.68, D(G(z)): 0.31
# Epoch [73/100], Step [400/600], d_loss: 1.0184, g_loss: 1.4538, D(x): 0.64, D(G(z)): 0.29
# Epoch [73/100], Step [600/600], d_loss: 0.9781, g_loss: 1.5210, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0074.png
# Epoch [74/100], Step [200/600], d_loss: 1.1535, g_loss: 1.3482, D(x): 0.63, D(G(z)): 0.34
# Epoch [74/100], Step [400/600], d_loss: 0.8859, g_loss: 1.4770, D(x): 0.69, D(G(z)): 0.30
# Epoch [74/100], Step [600/600], d_loss: 1.0548, g_loss: 1.3813, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0075.png
# Epoch [75/100], Step [200/600], d_loss: 0.9119, g_loss: 1.2478, D(x): 0.72, D(G(z)): 0.35
# Epoch [75/100], Step [400/600], d_loss: 0.8208, g_loss: 1.8730, D(x): 0.69, D(G(z)): 0.26
# Epoch [75/100], Step [600/600], d_loss: 0.8524, g_loss: 1.5917, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0076.png
# Epoch [76/100], Step [200/600], d_loss: 0.9797, g_loss: 1.4451, D(x): 0.78, D(G(z)): 0.38
# Epoch [76/100], Step [400/600], d_loss: 0.8726, g_loss: 1.5705, D(x): 0.69, D(G(z)): 0.26
# Epoch [76/100], Step [600/600], d_loss: 1.0742, g_loss: 1.5263, D(x): 0.68, D(G(z)): 0.34
# Saving fake_images-0077.png
# Epoch [77/100], Step [200/600], d_loss: 1.0901, g_loss: 1.2973, D(x): 0.69, D(G(z)): 0.37
# Epoch [77/100], Step [400/600], d_loss: 1.0617, g_loss: 1.5398, D(x): 0.62, D(G(z)): 0.30
# Epoch [77/100], Step [600/600], d_loss: 0.8806, g_loss: 1.5630, D(x): 0.67, D(G(z)): 0.26
# Saving fake_images-0078.png
# Epoch [78/100], Step [200/600], d_loss: 0.7958, g_loss: 1.5600, D(x): 0.69, D(G(z)): 0.24
# Epoch [78/100], Step [400/600], d_loss: 0.9085, g_loss: 1.5151, D(x): 0.70, D(G(z)): 0.30
# Epoch [78/100], Step [600/600], d_loss: 0.8054, g_loss: 1.5510, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0079.png
# Epoch [79/100], Step [200/600], d_loss: 0.8481, g_loss: 1.8417, D(x): 0.74, D(G(z)): 0.30
# Epoch [79/100], Step [400/600], d_loss: 0.9019, g_loss: 1.5036, D(x): 0.71, D(G(z)): 0.30
# Epoch [79/100], Step [600/600], d_loss: 0.8542, g_loss: 1.4763, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0080.png
# Epoch [80/100], Step [200/600], d_loss: 1.1129, g_loss: 1.3459, D(x): 0.65, D(G(z)): 0.35
# Epoch [80/100], Step [400/600], d_loss: 0.9929, g_loss: 1.5280, D(x): 0.68, D(G(z)): 0.29
# Epoch [80/100], Step [600/600], d_loss: 1.1013, g_loss: 1.4627, D(x): 0.63, D(G(z)): 0.32
# Saving fake_images-0081.png
# Epoch [81/100], Step [200/600], d_loss: 0.7375, g_loss: 1.7148, D(x): 0.74, D(G(z)): 0.25
# Epoch [81/100], Step [400/600], d_loss: 0.9548, g_loss: 1.8019, D(x): 0.65, D(G(z)): 0.28
# Epoch [81/100], Step [600/600], d_loss: 0.9045, g_loss: 1.1850, D(x): 0.78, D(G(z)): 0.38
# Saving fake_images-0082.png
# Epoch [82/100], Step [200/600], d_loss: 0.6628, g_loss: 1.7879, D(x): 0.78, D(G(z)): 0.26
# Epoch [82/100], Step [400/600], d_loss: 0.7634, g_loss: 1.7930, D(x): 0.75, D(G(z)): 0.29
# Epoch [82/100], Step [600/600], d_loss: 0.8829, g_loss: 1.4787, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0083.png
# Epoch [83/100], Step [200/600], d_loss: 0.8750, g_loss: 1.5673, D(x): 0.69, D(G(z)): 0.31
# Epoch [83/100], Step [400/600], d_loss: 0.7777, g_loss: 1.5556, D(x): 0.75, D(G(z)): 0.29
# Epoch [83/100], Step [600/600], d_loss: 0.8377, g_loss: 1.4685, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0084.png
# Epoch [84/100], Step [200/600], d_loss: 0.9449, g_loss: 1.8462, D(x): 0.68, D(G(z)): 0.30
# Epoch [84/100], Step [400/600], d_loss: 0.9002, g_loss: 1.2028, D(x): 0.74, D(G(z)): 0.35
# Epoch [84/100], Step [600/600], d_loss: 0.9849, g_loss: 1.2482, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0085.png
# Epoch [85/100], Step [200/600], d_loss: 1.0428, g_loss: 1.5356, D(x): 0.70, D(G(z)): 0.36
# Epoch [85/100], Step [400/600], d_loss: 0.9633, g_loss: 1.7451, D(x): 0.69, D(G(z)): 0.27
# Epoch [85/100], Step [600/600], d_loss: 0.8694, g_loss: 1.6169, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0086.png
# Epoch [86/100], Step [200/600], d_loss: 0.9912, g_loss: 1.2443, D(x): 0.69, D(G(z)): 0.35
# Epoch [86/100], Step [400/600], d_loss: 0.8304, g_loss: 1.5419, D(x): 0.74, D(G(z)): 0.32
# Epoch [86/100], Step [600/600], d_loss: 1.1099, g_loss: 1.7931, D(x): 0.65, D(G(z)): 0.32
# Saving fake_images-0087.png
# Epoch [87/100], Step [200/600], d_loss: 0.8705, g_loss: 1.6289, D(x): 0.70, D(G(z)): 0.29
# Epoch [87/100], Step [400/600], d_loss: 1.1037, g_loss: 1.7838, D(x): 0.65, D(G(z)): 0.33
# Epoch [87/100], Step [600/600], d_loss: 0.8703, g_loss: 1.7347, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0088.png
# Epoch [88/100], Step [200/600], d_loss: 0.8732, g_loss: 1.5781, D(x): 0.72, D(G(z)): 0.31
# Epoch [88/100], Step [400/600], d_loss: 0.9583, g_loss: 1.7461, D(x): 0.66, D(G(z)): 0.27
# Epoch [88/100], Step [600/600], d_loss: 0.8423, g_loss: 1.8501, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0089.png
# Epoch [89/100], Step [200/600], d_loss: 0.8677, g_loss: 1.5639, D(x): 0.70, D(G(z)): 0.29
# Epoch [89/100], Step [400/600], d_loss: 0.9374, g_loss: 1.3140, D(x): 0.75, D(G(z)): 0.37
# Epoch [89/100], Step [600/600], d_loss: 0.9892, g_loss: 1.3112, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0090.png
# Epoch [90/100], Step [200/600], d_loss: 1.0220, g_loss: 1.4352, D(x): 0.69, D(G(z)): 0.36
# Epoch [90/100], Step [400/600], d_loss: 1.0570, g_loss: 1.5495, D(x): 0.67, D(G(z)): 0.35
# Epoch [90/100], Step [600/600], d_loss: 0.9419, g_loss: 1.5472, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0091.png
# Epoch [91/100], Step [200/600], d_loss: 1.0443, g_loss: 1.3157, D(x): 0.64, D(G(z)): 0.30
# Epoch [91/100], Step [400/600], d_loss: 0.9282, g_loss: 1.4114, D(x): 0.71, D(G(z)): 0.32
# Epoch [91/100], Step [600/600], d_loss: 0.9112, g_loss: 1.4403, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0092.png
# Epoch [92/100], Step [200/600], d_loss: 0.8915, g_loss: 1.5789, D(x): 0.68, D(G(z)): 0.28
# Epoch [92/100], Step [400/600], d_loss: 0.7700, g_loss: 1.4640, D(x): 0.74, D(G(z)): 0.29
# Epoch [92/100], Step [600/600], d_loss: 0.9471, g_loss: 1.3018, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0093.png
# Epoch [93/100], Step [200/600], d_loss: 0.9578, g_loss: 1.5538, D(x): 0.67, D(G(z)): 0.30
# Epoch [93/100], Step [400/600], d_loss: 0.7376, g_loss: 1.5462, D(x): 0.73, D(G(z)): 0.28
# Epoch [93/100], Step [600/600], d_loss: 1.0314, g_loss: 1.4514, D(x): 0.63, D(G(z)): 0.32
# Saving fake_images-0094.png
# Epoch [94/100], Step [200/600], d_loss: 1.0018, g_loss: 1.3527, D(x): 0.65, D(G(z)): 0.33
# Epoch [94/100], Step [400/600], d_loss: 0.9921, g_loss: 1.6595, D(x): 0.69, D(G(z)): 0.31
# Epoch [94/100], Step [600/600], d_loss: 0.8167, g_loss: 1.8574, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0095.png
# Epoch [95/100], Step [200/600], d_loss: 0.9483, g_loss: 1.5596, D(x): 0.67, D(G(z)): 0.30
# Epoch [95/100], Step [400/600], d_loss: 0.8917, g_loss: 1.1954, D(x): 0.71, D(G(z)): 0.30
# Epoch [95/100], Step [600/600], d_loss: 0.8905, g_loss: 1.5234, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0096.png
# Epoch [96/100], Step [200/600], d_loss: 0.9376, g_loss: 1.8376, D(x): 0.67, D(G(z)): 0.29
# Epoch [96/100], Step [400/600], d_loss: 0.9107, g_loss: 1.5742, D(x): 0.67, D(G(z)): 0.27
# Epoch [96/100], Step [600/600], d_loss: 0.9140, g_loss: 1.3651, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0097.png
# Epoch [97/100], Step [200/600], d_loss: 1.0894, g_loss: 1.2212, D(x): 0.71, D(G(z)): 0.39
# Epoch [97/100], Step [400/600], d_loss: 0.9520, g_loss: 1.6537, D(x): 0.64, D(G(z)): 0.26
# Epoch [97/100], Step [600/600], d_loss: 0.9206, g_loss: 1.6062, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0098.png
# Epoch [98/100], Step [200/600], d_loss: 1.0412, g_loss: 1.6766, D(x): 0.66, D(G(z)): 0.31
# Epoch [98/100], Step [400/600], d_loss: 1.0213, g_loss: 1.5118, D(x): 0.70, D(G(z)): 0.36
# Epoch [98/100], Step [600/600], d_loss: 0.9915, g_loss: 1.3218, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0099.png
# Epoch [99/100], Step [200/600], d_loss: 0.8904, g_loss: 1.5013, D(x): 0.66, D(G(z)): 0.27
# Epoch [99/100], Step [400/600], d_loss: 0.8883, g_loss: 1.4851, D(x): 0.67, D(G(z)): 0.26
# Epoch [99/100], Step [600/600], d_loss: 0.9875, g_loss: 1.6367, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0100.png
# CPU times: user 31min 12s, sys: 18.8 s, total: 31min 31s
# Wall time: 31min 27s

# %%
# show output after epochs training
Image(os.path.join(sample_dir, 'fake_images-0098.png'))

# %%
# show the discrimator loss and generator loss
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
# plot the accuracy of discrimator
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
